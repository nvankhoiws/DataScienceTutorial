# %%
import pandas as pd
import numpy as numpy

fandango = pd.read_csv('fandango_score_comparison.csv')
fandango.head(10)
# Out:
#                              FILM  RottenTomatoes  RottenTomatoes_User  \
# 0  Avengers: Age of Ultron (2015)              74                   86
# 1               Cinderella (2015)              85                   80
# 2                  Ant-Man (2015)              80                   90
# 3          Do You Believe? (2015)              18                   84
# 4   Hot Tub Time Machine 2 (2015)              14                   28
# 5        The Water Diviner (2015)              63                   62
# 6           Irrational Man (2015)              42                   53
# 7                 Top Five (2014)              86                   64
# 8    Shaun the Sheep Movie (2015)              99                   82
# 9             Love & Mercy (2015)              89                   87
#
#    Metacritic  Metacritic_User  IMDB  Fandango_Stars  Fandango_Ratingvalue  \
# 0          66              7.1   7.8             5.0                   4.5
# ...

# %%
series_film = fandango['FILM']
print(series_film[0:6])
series_rt = fandango['RottenTomatoes']
print(series_rt[0:6])
# Out:
# 0    Avengers: Age of Ultron (2015)
# 1                 Cinderella (2015)
# 2                    Ant-Man (2015)
# 3            Do You Believe? (2015)
# 4     Hot Tub Time Machine 2 (2015)
# 5          The Water Diviner (2015)
# Name: FILM, dtype: object
# 0    74
# 1    85
# 2    80
# 3    18
# 4    14
# 5    63
# Name: RottenTomatoes, dtype: int64

# %%
series_custom = pd.Series(index=series_film.values,data=series_rt.values)
# series_custom['Cinderella (2015)']
series_custom.loc['Cinderella (2015)']
series_custom[['Minions (2015)', 'Leviathan (2014)']]
fiveten=series_custom[5:11]
print(fiveten)
# Out:
# The Water Diviner (2015)             63
# Irrational Man (2015)                42
# Top Five (2014)                      86
# Shaun the Sheep Movie (2015)         99
# Love & Mercy (2015)                  89
# Far From The Madding Crowd (2015)    84
# dtype: int64

# %%
original_index = series_custom.index
list_original_index = original_index.tolist()
sorted_list_original_index = sorted(list_original_index)
sorted_by_index=series_custom.reindex(index=sorted_list_original_index)
sorted_by_index

# sort by index and sort by value
sc2=series_custom.sort_index(inplace=False)
sc3=series_custom.sort_values(inplace=False)
print(sc2.head(10))
print(sc3.iloc[0:10])
# Out:
# '71 (2015)                    97
# 5 Flights Up (2015)           52
# A Little Chaos (2015)         40
# A Most Violent Year (2014)    90
# About Elly (2015)             97
# Aloha (2015)                  19
# American Sniper (2015)        72
# American Ultra (2015)         46
# Amy (2015)                    97
# Annie (2014)                  27
# dtype: int64
# Paul Blart: Mall Cop 2 (2015)     5
# Hitman: Agent 47 (2015)           7
# Hot Pursuit (2015)                8
# Fantastic Four (2015)             9
# Taken 3 (2015)                    9
# The Boy Next Door (2015)         10
# The Loft (2015)                  11
# Unfinished Business (2015)       11
# Mortdecai (2015)                 12
# Seventh Son (2015)               12
# dtype: int64

# %%
# 7. Transforming Columns With Vectorized Operations
# Normalized the series_custom to 0 to 5 point scale
series_normalized = pd.Series(index=series_custom.index.tolist(),data=(series_custom.values/20).tolist())
series_normalized
# Out:
# Avengers: Age of Ultron (2015)                    3.70
# Cinderella (2015)                                 4.25
# Ant-Man (2015)                                    4.00
# Do You Believe? (2015)                            0.90
# Hot Tub Time Machine 2 (2015)                     0.70
# The Water Diviner (2015)                          3.15
# Irrational Man (2015)                             2.10
# Top Five (2014)                                   4.30
# Shaun the Sheep Movie (2015)                      4.95
# Love & Mercy (2015)                               4.45
# Far From The Madding Crowd (2015)                 4.20
# Black Sea (2015)                                  4.10
# Leviathan (2014)                                  4.95
# Unbroken (2014)                                   2.55
# The Imitation Game (2014)                         4.50
# Taken 3 (2015)                                    0.45
# Ted 2 (2015)                                      2.30
# ...

# %%
# 8. Comparing and Filtering
criteria_one = series_custom > 50
criteria_two = series_custom < 75
both_criteria=series_custom[criteria_one & criteria_two]

# 9. Alignment
# Calculate mean of two series
# Way no 1
rt_critics = pd.Series(fandango['RottenTomatoes'].values, index=fandango['FILM'])
rt_users = pd.Series(fandango['RottenTomatoes_User'].values, index=fandango['FILM'])
rt_mean= pd.Series(data=(rt_critics+rt_users)/2,index=fandango['FILM'])
# rt_mean

# Way no 2
temp_df = pd.concat([rt_critics,rt_users],axis=1)
# temp_df
# print(temp_df.index)
# mean_of_temp_df=
temp_df['mean']= temp_df.mean(axis=1)
# mean_of_temp_df
# temp_df
rt_mean=pd.Series(data=temp_df['mean'],index=fandango['FILM'])
rt_mean
# Out:
# FILM
# Avengers: Age of Ultron (2015)                    80.0
# Cinderella (2015)                                 82.5
# Ant-Man (2015)                                    85.0
# Do You Believe? (2015)                            51.0
# Hot Tub Time Machine 2 (2015)                     21.0
# The Water Diviner (2015)                          62.5
# Irrational Man (2015)                             47.5
# Top Five (2014)                                   75.0
# Shaun the Sheep Movie (2015)                      90.5
# Love & Mercy (2015)                               88.0
# Far From The Madding Crowd (2015)                 80.5
# Black Sea (2015)                                  71.0
# Leviathan (2014)                                  89.0
# Unbroken (2014)                                   60.5
# The Imitation Game (2014)                         91.0
# Taken 3 (2015)                                    27.5
# Ted 2 (2015)                                      52.0
# ...
